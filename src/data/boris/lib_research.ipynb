# %%
from dotenv import load_dotenv; 
load_dotenv()
import os
from moexalgo import session, Market, Ticker
import datetime as dt
from tickers import TICKERS
import pandas as pd

def getFormattedDate(timestamp : dt.datetime):
    days = str(timestamp.day)
    if (len(days) < 2):
        days = '0' + days
    month = str(timestamp.month)
    if (len(month) < 2):
        month = '0' + month
    year = str(timestamp.year)
    return f"{year}-{month}-{days}"

def TickerName(ticker, timestamp1:dt.datetime):
    return f"{ticker}_{getFormattedDate(timestamp1)}.csv"

MOEX_TOKEN = os.getenv("MOEX_TOKEN")

session.TOKEN = MOEX_TOKEN

dataBegin = "2011-01-01"
dataBegin = "2025-01-01"
dataEnd = "2025-01-10"


def get_day(ticker : Ticker, dateBegin, dateEnd, filename):
    data_ob = ticker.obstats(start=dateBegin, end=dateEnd)
    data_tr = ticker.tradestats(start=dateBegin, end=dateEnd)
    data_or = ticker.orderstats(start=dateBegin, end=dateEnd)    
    return (data_tr, data_or, data_ob)
    print(data_or.columns, data_ob.columns, data_tr.columns)

    data = pd.merge(data_ob, data_tr, on=("tradedate", "tradetime"), how="inner")
    data = pd.merge(data, data_or, on=("tradedate", "tradetime"), how="inner")
    data.to_csv(filename)

def load_ticker(tickerSymb, dateBegin, dateEnd):
    begin = dt.datetime.strptime(dateBegin, "%Y-%m-%d").date()
    end = dt.datetime.strptime(dateEnd, "%Y-%m-%d").date()
    ticker = Ticker(tickerSymb)

    while (begin <= end): 
        name = f"./{tickerSymb}/{TickerName(tickerSymb, begin)}"
        cur = getFormattedDate(begin)
        print(f"loading {cur}",end=" ")
        begin += dt.timedelta(days=1)
        curp1 = getFormattedDate(begin)

        get_day(ticker, cur, curp1, name)
        print("loaded;")
    
#load_ticker(TICKERS[0], dataBegin, dataEnd)
# Out:
# 245

# %%
data0 = get_day(Ticker("SBER"), dataBegin, dataEnd, "")

# %%
def DataTransform(data_ob, data_tr, data_or):
    data_ob = data_ob.drop(columns=["systime"])
    data_ob.rename(columns={'val_b': 'val_b_obstat', 'val_s': 'val_s_obstat', 'vol_b': 'vol_b_obstat', 'vol_s': 'vol_s_obstat'}, inplace=True)
    
    data_tr = data_tr.drop(columns=["systime"])
    
    data_or = data_or.drop(columns=["systime"])
    data_or.rename(columns={'val_b': 'val_b_order', 'val_s': 'val_s_order', 'vol_b': 'vol_b_order', 'vol_s': 'vol_s_order'}, inplace=True)

    return data_ob, data_tr, data_or

#print(*sorted(list(data0[0].columns)), sep="\n",end="\n\n")
data1 = DataTransform(*data0)
print(*sorted(list(data1[0].columns)), sep="\n",end="\n\n")
# Out:
# disb
# pr_change
# pr_close
# pr_high
# pr_low
# pr_open
# pr_std
# pr_vwap
# pr_vwap_b
# pr_vwap_s
# sec_pr_close
# sec_pr_high
# sec_pr_low
# sec_pr_open
# ticker
# tradedate
# trades
# trades_b
# trades_s
# tradetime
# val
# val_b_obstat
# val_s_obstat
# vol
# vol_b_obstat
# vol_s_obstat

# %%
data2 = pd.merge(data1[0], data1[1], on=("tradedate", "tradetime", "ticker"), how="inner")
data3 = pd.merge(data2, data1[2], on=("tradedate", "tradetime", "ticker"), how="inner")
print(*sorted(list(data3.columns)), sep="\n",end="\n\n")
data3.to_csv("look.csv", index=False)
# Out:
# cancel_orders
# cancel_orders_b
# cancel_orders_s
# cancel_val
# cancel_val_b
# cancel_val_s
# cancel_vol
# cancel_vol_b
# cancel_vol_s
# cancel_vwap_b
# cancel_vwap_s
# disb
# imbalance_val
# imbalance_val_bbo
# imbalance_vol
# imbalance_vol_bbo
# levels_b
# levels_s
# pr_change
# pr_close
# pr_high
# pr_low
# pr_open
# pr_std
# pr_vwap
# pr_vwap_b
# pr_vwap_s
# put_orders
# put_orders_b
# put_orders_s
# put_val
# put_val_b
# put_val_s
# put_vol
# put_vol_b
# put_vol_s
# put_vwap_b
# put_vwap_s
# sec_pr_close
# sec_pr_high
# sec_pr_low
# sec_pr_open
# spread_1mio
# spread_bbo
# spread_lv10
# ticker
# tradedate
# trades
# trades_b
# trades_s
# tradetime
# val
# val_b_obstat
# val_b_order
# val_s_obstat
# val_s_order
# vol
# vol_b_obstat
# vol_b_order
# vol_s_obstat
# vol_s_order
# vwap_b
# vwap_b_1mio
# vwap_s
# vwap_s_1mio

# %%
ids = data3["val_b_x"] != data3["val_b_y"]
data3[ids][["val_b_x", "val_b_y"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_b_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ids = data3["val_b_x"] != data3["val_b_y"]
#       2 data3[ids][["val_b_x", "val_b_y"]]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'val_b_x'

# %%
print(data[0].columns, data[1].columns, data[2].columns, sep="\n\n")
# Out:
# Index(['tradedate', 'tradetime', 'ticker', 'pr_open', 'pr_high', 'pr_low',
#        'pr_close', 'pr_std', 'vol', 'val', 'trades', 'pr_vwap', 'pr_change',
#        'trades_b', 'trades_s', 'val_b', 'val_s', 'vol_b', 'vol_s', 'disb',
#        'pr_vwap_b', 'pr_vwap_s', 'systime', 'sec_pr_open', 'sec_pr_high',
#        'sec_pr_low', 'sec_pr_close'],
#       dtype='str')
#
# Index(['tradedate', 'tradetime', 'ticker', 'put_orders_b', 'put_orders_s',
#        'put_val_b', 'put_val_s', 'put_vol_b', 'put_vol_s', 'put_vwap_b',
#        'put_vwap_s', 'put_vol', 'put_val', 'put_orders', 'cancel_orders_b',
#        'cancel_orders_s', 'cancel_val_b', 'cancel_val_s', 'cancel_vol_b',
#        'cancel_vol_s', 'cancel_vwap_b', 'cancel_vwap_s', 'cancel_vol',
#        'cancel_val', 'cancel_orders', 'systime'],
#       dtype='str')
#
# Index(['tradedate', 'tradetime', 'ticker', 'spread_bbo', 'spread_lv10',
#        'spread_1mio', 'levels_b', 'levels_s', 'vol_b', 'vol_s', 'val_b',
#        'val_s', 'imbalance_vol_bbo', 'imbalance_val_bbo', 'imbalance_vol',
#        'imbalance_val', 'vwap_b', 'vwap_s', 'vwap_b_1mio', 'vwap_s_1mio',
#        'systime'],
#       dtype='str')

# %%
print(*sorted(list(data2.columns)), sep="\n")
print(len(set(data2.columns)))
a = list(data2.columns)

for i in a:
    if ('_x' in i):
        print(i)
# Out:
# cancel_orders
# cancel_orders_b
# cancel_orders_s
# cancel_val
# cancel_val_b
# cancel_val_s
# cancel_vol
# cancel_vol_b
# cancel_vol_s
# cancel_vwap_b
# cancel_vwap_s
# disb
# pr_change
# pr_close
# pr_high
# pr_low
# pr_open
# pr_std
# pr_vwap
# pr_vwap_b
# pr_vwap_s
# put_orders
# put_orders_b
# put_orders_s
# put_val
# put_val_b
# put_val_s
# put_vol
# put_vol_b
# put_vol_s
# put_vwap_b
# put_vwap_s
# sec_pr_close
# sec_pr_high
# sec_pr_low
# sec_pr_open
# systime_x
# systime_y
# ticker
# tradedate
# trades
# trades_b
# trades_s
# tradetime
# val
# val_b
# val_s
# vol
# vol_b
# vol_s
# 50
# systime_x

# %%
print(data2["systime_x"], data2["systime_y"])
# Out:
# 0      2025-01-03 10:05:10
# 1      2025-01-03 10:10:10
# 2      2025-01-03 10:15:10
# 3      2025-01-03 10:20:10
# 4      2025-01-03 10:25:10
#               ...
# 800    2025-01-10 23:30:10
# 801    2025-01-10 23:35:10
# 802    2025-01-10 23:40:10
# 803    2025-01-10 23:45:10
# 804    2025-01-10 23:50:10
# Name: systime_x, Length: 805, dtype: str 0      2025-01-03 10:05:13
# 1      2025-01-03 10:10:13
# 2      2025-01-03 10:15:12
# 3      2025-01-03 10:20:22
# 4      2025-01-03 10:25:12
#               ...
# 800    2025-01-10 23:30:14
# 801    2025-01-10 23:35:14
# 802    2025-01-10 23:40:14
# 803    2025-01-10 23:45:14
# 804    2025-01-10 23:50:14
# Name: systime_y, Length: 805, dtype: str

# %%
ids = data2["systime_y"] != data2["systime_x"]

print(ids)
print(data2[ids][("systime_y", "systime_x")])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 800    True
# 801    True
# 802    True
# 803    True
# 804    True
# Length: 805, dtype: bool
#       tradedate tradetime ticker  pr_open  pr_high  pr_low  pr_close  pr_std  \
# 0    2025-01-03  10:05:00   SBER   279.99   280.41  279.20    279.54  0.0001
# 1    2025-01-03  10:10:00   SBER   279.54   279.56  278.11    278.40  0.0001
# 2    2025-01-03  10:15:00   SBER   278.53   279.21  278.14    278.40  0.0001
# 3    2025-01-03  10:20:00   SBER   278.42   279.01  278.30    278.32  0.0000
# 4    2025-01-03  10:25:00   SBER   278.32   278.44  277.77    277.80  0.0000
# ..          ...       ...    ...      ...      ...     ...       ...     ...
# 800  2025-01-10  23:30:00   SBER   278.86   279.03  278.85    279.03  0.0001
# 801  2025-01-10  23:35:00   SBER   279.03   279.04  278.75    278.80  0.0001
# 802  2025-01-10  23:40:00   SBER   278.80   278.96  278.80    278.89  0.0001
# 803  2025-01-10  23:45:00   SBER   278.89   279.03  278.83    278.96  0.0001
# 804  2025-01-10  23:50:00   SBER   278.94   278.99  278.47    278.77  0.0001
#
#         vol        val  ...  cancel_val_b  cancel_val_s  cancel_vol_b  \
# 0    241287  675113092  ...   21434894764   27071918391       7664438
# 1    228933  638680676  ...   36033349987   41788054262      12931057
# 2    101954  284080626  ...   44081210119   39096797762      15823471
# 3     61568  171522940  ...   16225824374   14800182586       5824827
# 4    117768  327574944  ...    5792588440   12755965881       2084430
# ..      ...        ...  ...           ...           ...           ...
# 800   14267   39794558  ...     331046565     422766287        118854
# 801   12178   33961269  ...     484471458    1805337167        173838
# 802    4922   13726514  ...     139581360     592420147         50101
# 803   22296   62192211  ...     370925179     578302701        133170
# 804   31457   87688837  ...     296391891     351441671        106761
#
#      cancel_vol_s  cancel_vwap_b  cancel_vwap_s  cancel_vol   cancel_val  \
# 0         9668789         279.67         279.99    17333227  48506813155
# 1        14981542         278.66         278.93    27912599  77821404249
# 2        14022901         278.58         278.81    29846372  83178007881
# 3         5309202         278.56         278.76    11134029  31026006961
# 4         4584570         277.90         278.24     6669000  18548554321
# ..            ...            ...            ...         ...          ...
# 800        151471         278.53         279.11      270325    753812852
# 801        646858         278.69         279.09      820696   2289808626
# 802        212294         278.60         279.06      262395    732001507
# 803        207176         278.54         279.14      340346    949227881
# 804        125736         277.62         279.51      232497    647833562
#
#      cancel_orders            systime_y
# 0           104494  2025-01-03 10:05:13
# 1           159397  2025-01-03 10:10:13
# 2           154914  2025-01-03 10:15:12
# 3            63284  2025-01-03 10:20:22
# 4            34879  2025-01-03 10:25:12
# ..             ...                  ...
# 800           1392  2025-01-10 23:30:14
# 801           2637  2025-01-10 23:35:14
# 802           1164  2025-01-10 23:40:14
# 803           1868  2025-01-10 23:45:14
# 804           1736  2025-01-10 23:50:14
#
# [805 rows x 50 columns]

# %%
def DataTransform(data_ob, data_tr, data_or):
    data_ob = data_ob.drop(columns=["systime"])
    data_ob.rename(columns={'val_b': 'val_b_obstat', 'val_s': 'val_s_obstat', 'vol_b': 'vol_b_obstat', 'vol_s': 'vol_s_obstat'}, inplace=True)
    
    data_tr = data_tr.drop(columns=["systime"])
    
    data_or = data_or.drop(columns=["systime"])
    data_or.rename(columns={'val_b': 'val_b_order', 'val_s': 'val_s_order', 'vol_b': 'vol_b_order', 'vol_s': 'vol_s_order'}, inplace=True)

    data = pd.merge(data_ob, data_tr, on=("tradedate", "tradetime", "ticker"), how="inner")
    data = pd.merge(data, data_ob, on=("tradedate", "tradetime", "ticker"), how="inner")

    return data

# %%
data1 = DataTransform(*data0)
data1
# Out:
#       tradedate tradetime ticker  pr_open_x  pr_high_x  pr_low_x  pr_close_x  \
# 0    2025-01-03  10:05:00   SBER     279.99     280.41    279.20      279.54
# 1    2025-01-03  10:10:00   SBER     279.54     279.56    278.11      278.40
# 2    2025-01-03  10:15:00   SBER     278.53     279.21    278.14      278.40
# 3    2025-01-03  10:20:00   SBER     278.42     279.01    278.30      278.32
# 4    2025-01-03  10:25:00   SBER     278.32     278.44    277.77      277.80
# ..          ...       ...    ...        ...        ...       ...         ...
# 800  2025-01-10  23:30:00   SBER     278.86     279.03    278.85      279.03
# 801  2025-01-10  23:35:00   SBER     279.03     279.04    278.75      278.80
# 802  2025-01-10  23:40:00   SBER     278.80     278.96    278.80      278.89
# 803  2025-01-10  23:45:00   SBER     278.89     279.03    278.83      278.96
# 804  2025-01-10  23:50:00   SBER     278.94     278.99    278.47      278.77
#
#      pr_std_x   vol_x      val_x  ...  val_s_obstat_y  vol_b_obstat_y  \
# 0      0.0001  241287  675113092  ...       383391941          104248
# 1      0.0001  228933  638680676  ...       420828593           78102
# 2      0.0001  101954  284080626  ...       157516287           45401
# 3      0.0000   61568  171522940  ...        88642118           29745
# 4      0.0000  117768  327574944  ...       250086654           27861
# ..        ...     ...        ...  ...             ...             ...
# 800    0.0001   14267   39794558  ...         4540885           12639
# 801    0.0001   12178   33961269  ...        28791975            1853
# 802    0.0001    4922   13726514  ...         2309117            4094
# 803    0.0001   22296   62192211  ...        18188284           15774
# 804    0.0001   31457   87688837  ...        71091141            5953
#
#      vol_s_obstat_y  disb_y  pr_vwap_b_y  pr_vwap_s_y  sec_pr_open_y  \
# 0            137039   -0.14       279.83       279.77              1
# 1            150831   -0.32       278.93       279.01              1
# 2             56553   -0.11       278.77       278.53              2
# 3             31823   -0.03       278.64       278.55              1
# 4             89907   -0.53       278.12       278.16              1
# ..              ...     ...          ...          ...            ...
# 800            1628    0.77       278.93       278.92              9
# 801           10325   -0.70       278.97       278.86              6
# 802             828    0.66       278.88       278.88              6
# 803            6522    0.41       278.96       278.88              2
# 804           25504   -0.62       278.81       278.75              2
#
#      sec_pr_high_y  sec_pr_low_y  sec_pr_close_y
# 0              159           102             300
# 1                1           232             300
# 2              139             9             300
# 3              167           289             300
# 4               41           274             300
# ..             ...           ...             ...
# 800            271            10             295
# 801             10           224             293
# 802             15             6             300
# 803             86            99             298
# 804             30           275             298
#
# [805 rows x 71 columns]
